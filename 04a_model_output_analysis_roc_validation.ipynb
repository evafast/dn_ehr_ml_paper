# %% [markdown]
# **04a_model_output_analysis_roc_validation**
#
# - Plotting of ROC and confusion matrix on validation dataset
#
# used this container:
# ml:1.0

# %%
# load packages
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import seaborn as sns
import datetime


import shap

import tarfile
import pickle as pkl

import xgboost as xgb

import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn import metrics

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import classification_report

import os
from urllib.parse import urlparse

from helper_functions import *

# %%
# define paths
base_dir = '/home/jovyan/work/Goldfinch/ML_paper/'
output_suffix = 'output_files/training_output/'
suffix = 'raw_data/intermediate_files/'

# %%
# read the model files
df_model = pd.read_csv(f'{base_dir}raw_data/reprocessed_model_log.csv')

executionid = 1
 
file_name_base = str(df_model[df_model['ExecutionID'] == executionid][['aggregation_time','gap']].values[0][0]) + '_years_' + str(df_model[df_model['ExecutionID'] == executionid][['aggregation_time','gap']].values[0][1])    

#load the colnames
colnames = pd.read_csv(f'{base_dir}{suffix}{file_name_base}/column_header.csv', header = None)
colnames = colnames[0].tolist()

X_val = pd.read_csv(f'{base_dir}{suffix}{file_name_base}/validation.csv', names=colnames, header=None)
Y_val = X_val.iloc[:,0]
X_val = X_val.iloc[:,1:] #drop the first column which is the outcome variable

X_valD = X_val

model = xgb.XGBClassifier()
model.load_model(f'{base_dir}{suffix}{file_name_base}/model.json')

y_pred_bin = model.predict(X_valD) > 0.5
y_pred = model.predict_proba(X_valD)

print(file_name_base)

filepath = f'{base_dir}{output_suffix}'
input_file_name_variable = file_name_base + '_val'

conf_class_report(y_pred_bin, Y_val, filepath, input_file_name_variable, save_fig = True)

plot_roc_curve(y_pred[:,1], Y_val, filepath, input_file_name_variable, save_fig = True)
# Out:
# 0_years_0
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.94      0.86        52
#          1.0       0.89      0.65      0.75        37
#
#     accuracy                           0.82        89
#    macro avg       0.84      0.80      0.80        89
# weighted avg       0.83      0.82      0.81        89

# %%
pd.show_versions()
# Out:
# Setuptools is replacing distutils.
# INSTALLED VERSIONS
# ------------------
# commit           : 87cfe4e38bafe7300a6003a1d18bd80f3f77c763
# python           : 3.10.6.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.76-linuxkit
# Version          : #1 SMP PREEMPT Mon Nov 8 11:22:26 UTC 2021
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.5.0
# numpy            : 1.23.3
# pytz             : 2022.2.1
# dateutil         : 2.8.2
# setuptools       : 65.4.0
# pip              : 22.2.2
# Cython           : 0.29.32
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.1
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.1.2
# IPython          : 8.5.0
# pandas_datareader: None
# bs4              : 4.11.1
# bottleneck       : 1.3.5
# brotli           :
# fastparquet      : None
# fsspec           : 2022.8.2
# gcsfs            : None
# matplotlib       : 3.5.3
# numba            : 0.56.2
# numexpr          : 2.8.3
# odfpy            : None
# openpyxl         : 3.0.10
# pandas_gbq       : None
# pyarrow          : 10.0.0
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.9.1
# snappy           : None
# sqlalchemy       : 1.4.41
# tables           : 3.7.0
# tabulate         : None
# xarray           : None
# xlrd             : 2.0.1
# xlwt             : None
# zstandard        : None
# tzdata           : None

# %%
! pip list
# Out:
# Package                           Version
# --------------------------------- -----------
# alembic                           1.8.1
# altair                            4.2.0
# anyio                             3.6.1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# asttokens                         2.0.8
# async-generator                   1.10
# attrs                             22.1.0
# Babel                             2.10.3
# backcall                          0.2.0
# backports.functools-lru-cache     1.6.4
# beautifulsoup4                    4.11.1
# bleach                            5.0.1
# blinker                           1.4
# bokeh                             2.4.3
# Bottleneck                        1.3.5
# brotlipy                          0.7.0
# cached-property                   1.5.2
# catboost                          1.1.1
# certifi                           2022.9.24
# certipy                           0.1.3
# cffi                              1.15.1
# charset-normalizer                2.1.1
# classeval                         0.1.13
# click                             8.1.3
# cloudpickle                       2.2.0
# colorama                          0.4.5
# colourmap                         1.1.10
# conda                             4.14.0
# conda-package-handling            1.9.0
# contourpy                         1.0.5
# cryptography                      37.0.4
# cycler                            0.11.0
# Cython                            0.29.32
# cytoolz                           0.12.0
# dask                              2022.9.1
# debugpy                           1.6.3
# decorator                         5.1.1
# defusedxml                        0.7.1
# df2onehot                         1.0.1
# dill                              0.3.5.1
# distributed                       2022.9.1
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# executing                         1.1.0
# fastjsonschema                    2.16.2
# flit_core                         3.7.1
# fonttools                         4.37.3
# fsspec                            2022.8.2
# funcsigs                          1.0.2
# future                            0.18.2
# gmpy2                             2.1.2
# graphviz                          0.20.1
# greenlet                          1.1.3
# h5py                              3.7.0
# HeapDict                          1.0.1
# hgboost                           1.1.3
# htmlmin                           0.1.12
# hyperopt                          0.2.7
# idna                              3.4
# imagecodecs                       2022.9.26
# ImageHash                         4.3.1
# imageio                           2.22.0
# importlib-metadata                4.11.4
# importlib-resources               5.9.0
# ipykernel                         6.16.0
# ipympl                            0.9.2
# ipython                           8.5.0
# ipython-genutils                  0.2.0
# ipywidgets                        8.0.2
# jedi                              0.18.1
# Jinja2                            3.1.2
# joblib                            1.2.0
# json5                             0.9.5
# jsonschema                        4.16.0
# jupyter-client                    7.3.4
# jupyter_core                      4.11.1
# jupyter-server                    1.19.1
# jupyter-telemetry                 0.1.0
# jupyterhub                        3.0.0
# jupyterlab                        3.4.7
# jupyterlab-pygments               0.2.2
# jupyterlab_server                 2.15.2
# jupyterlab-widgets                3.0.3
# kiwisolver                        1.4.4
# lckr-jupyterlab-variableinspector 3.0.9
# libmambapy                        0.25.0
# lightgbm                          3.3.3
# llvmlite                          0.39.1
# locket                            1.0.0
# lxml                              4.9.1
# lz4                               4.0.0
# Mako                              1.2.3
# mamba                             0.25.0
# MarkupSafe                        2.1.1
# matplotlib                        3.5.3
# matplotlib-inline                 0.1.6
# missingno                         0.5.1
# mistune                           2.0.4
# mpmath                            1.2.1
# msgpack                           1.0.4
# multimethod                       1.9
# munkres                           1.1.4
# nbclassic                         0.4.3
# nbclient                          0.6.8
# nbconvert                         7.0.0
# nbformat                          5.6.1
# nest-asyncio                      1.5.5
# networkx                          2.8.6
# notebook                          6.4.12
# notebook-shim                     0.1.0
# numba                             0.56.2
# numexpr                           2.8.3
# numpy                             1.23.3
# oauthlib                          3.2.1
# openpyxl                          3.0.10
# packaging                         21.3
# pamela                            1.0.0
# pandas                            1.5.0
# pandas-profiling                  3.4.0
# pandocfilters                     1.5.0
# parso                             0.8.3
# partd                             1.3.0
# patsy                             0.5.2
# pexpect                           4.8.0
# phik                              0.12.2
# pickleshare                       0.7.5
# Pillow                            9.2.0
# pip                               22.2.2
# pkgutil_resolve_name              1.3.10
# plotly                            5.11.0
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.31
# protobuf                          4.21.6
# psutil                            5.9.2
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py4j                              0.10.9.7
# pyarrow                           10.0.0
# pycosat                           0.6.3
# pycparser                         2.21
# pycurl                            7.45.1
# pydantic                          1.10.2
# Pygments                          2.13.0
# PyJWT                             2.5.0
# pyOpenSSL                         22.0.0
# pyparsing                         3.0.9
# pypickle                          1.1.0
# pyrsistent                        0.18.1
# PySocks                           1.7.1
# python-dateutil                   2.8.2
# python-json-logger                2.0.1
# pytz                              2022.2.1
# PyWavelets                        1.3.0
# PyYAML                            6.0
# pyzmq                             24.0.1
# requests                          2.28.1
# ruamel.yaml                       0.17.21
# ruamel.yaml.clib                  0.2.6
# ruamel-yaml-conda                 0.15.80
# scikit-image                      0.19.3
# scikit-learn                      1.1.2
# scipy                             1.9.1
# seaborn                           0.12.0
# Send2Trash                        1.8.0
# setuptools                        65.4.0
# shap                              0.41.0
# six                               1.16.0
# sklearn                           0.0.post1
# slicer                            0.0.7
# sniffio                           1.3.0
# sortedcontainers                  2.4.0
# soupsieve                         2.3.2.post1
# SQLAlchemy                        1.4.41
# stack-data                        0.5.1
# statsmodels                       0.13.2
# sympy                             1.10.1
# tables                            3.7.0
# tangled-up-in-unicode             0.2.0
# tblib                             1.7.0
# tenacity                          8.1.0
# terminado                         0.16.0
# threadpoolctl                     3.1.0
# tifffile                          2022.8.12
# tinycss2                          1.1.1
# tomli                             2.0.1
# toolz                             0.12.0
# tornado                           6.1
# tqdm                              4.64.1
# traitlets                         5.4.0
# treeplot                          0.1.16
# typing_extensions                 4.3.0
# unicodedata2                      14.0.0
# urllib3                           1.26.11
# visions                           0.7.5
# wcwidth                           0.2.5
# webencodings                      0.5.1
# websocket-client                  1.4.1
# wget                              3.2
# wheel                             0.37.1
# widgetsnbextension                4.0.3
# xgboost                           1.7.1
# xlrd                              2.0.1
# zict                              2.2.0
# zipp                              3.8.1
